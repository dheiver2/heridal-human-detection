# %%
# %pip install ultralytics --quiet
import ultralytics
ultralytics.checks()

# !nvidia-smi

# !ls
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5597.6/8062.4 GB disk)
# Thu May  9 15:01:52 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla P100-PCIE-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0              26W / 250W |      2MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import warnings

# Suprimir mensagens de advertência
warnings.filterwarnings("ignore")

# !pip install ultralytics==8.0.196 --quiet
# !pip install roboflow --quiet

# Restaurar mensagens de advertência padrão
warnings.filterwarnings("default")

from roboflow import Roboflow

# Suprimir mensagens de advertência
warnings.filterwarnings("ignore")

from roboflow import Roboflow
rf = Roboflow(api_key="1uaBIxC6yfhPjoHi8YF3")
project = rf.workspace("drone-internship").project("heridal-human-detection")
version = project.version(14)
dataset = version.download("yolov8")
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# jupyterlab 4.1.6 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.2 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.2.1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.11, to fix: `pip install ultralytics==8.0.196`
# Downloading Dataset Version Zip in Heridal-Human-Detection-14 to yolov8:: 100%|██████████| 291772/291772 [00:07<00:00, 39848.94it/s]
# Extracting Dataset Version Zip to Heridal-Human-Detection-14 in yolov8:: 100%|██████████| 5382/5382 [00:01<00:00, 5191.88it/s]

# %%
import yaml

# Caminho para o arquivo data.yaml
yaml_file_path = "/kaggle/working/Heridal-Human-Detection-14/data.yaml"

# Carregar o arquivo YAML
with open(yaml_file_path, 'r') as file:
    data = yaml.safe_load(file)

# Imprimir o conteúdo
print(data)
# Out:
# {'names': ['human'], 'nc': 1, 'roboflow': {'license': 'CC BY 4.0', 'project': 'heridal-human-detection', 'url': 'https://universe.roboflow.com/drone-internship/heridal-human-detection/dataset/14', 'version': 14, 'workspace': 'drone-internship'}, 'test': '../test/images', 'train': 'Heridal-Human-Detection-14/train/images', 'val': 'Heridal-Human-Detection-14/valid/images'}

# %%
import os
import yaml

# Define the directory where the 'images' folders are located
working_directory = "/kaggle/working"

# Define the directory containing the YAML files
yaml_directory = "/kaggle/working/Heridal-Human-Detection-14"

# Define the paths to the image folders
test_path = "/kaggle/working/Heridal-Human-Detection-14/test"
train_path = "/kaggle/working/Heridal-Human-Detection-14/train"
val_path = "/kaggle/working/Heridal-Human-Detection-14/valid"

# Define the path to the YAML file
yaml_file_path = os.path.join(yaml_directory, "data.yaml")

# Update the YAML file with the new image folder paths and class information
data = {
    'test': test_path,
    'train': train_path,
    'val': val_path,
    'nc': 1,  # Number of classes
    'names': ['humans']  # Class names
}

with open(yaml_file_path, 'w') as file:
    yaml.dump(data, file)

print("Image folder paths and class information successfully updated in the YAML file.")
# Out:
# Image folder paths and class information successfully updated in the YAML file.

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
